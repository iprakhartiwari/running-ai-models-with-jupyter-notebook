# %% [markdown]
# # Installing and Running AI Model

# %%
# !pip install tensorflow==2.12.0
# !pip install transformers==4.37.2
# Out:
# Requirement already satisfied: tensorflow==2.12.0 in c:\users\prakh\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.24)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (16.0.6)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.60.1)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\prakh\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\prakh\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\prakh\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.3.2)
# Requirement already satisfied: scipy>=1.9 in c:\users\prakh\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.11.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\prakh\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.28.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\prakh\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\prakh\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\prakh\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\prakh\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\prakh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\prakh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\prakh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\prakh\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prakh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prakh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prakh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prakh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\prakh\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\prakh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\prakh\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.2.2)
# Requirement already satisfied: transformers==4.37.2 in c:\users\prakh\anaconda3\lib\site-packages (4.37.2)
# Requirement already satisfied: filelock in c:\users\prakh\anaconda3\lib\site-packages (from transformers==4.37.2) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\prakh\anaconda3\lib\site-packages (from transformers==4.37.2) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\prakh\anaconda3\lib\site-packages (from transformers==4.37.2) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\prakh\anaconda3\lib\site-packages (from transformers==4.37.2) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\prakh\anaconda3\lib\site-packages (from transformers==4.37.2) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\prakh\anaconda3\lib\site-packages (from transformers==4.37.2) (2022.7.9)
# Requirement already satisfied: requests in c:\users\prakh\anaconda3\lib\site-packages (from transformers==4.37.2) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\prakh\anaconda3\lib\site-packages (from transformers==4.37.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\prakh\anaconda3\lib\site-packages (from transformers==4.37.2) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\prakh\anaconda3\lib\site-packages (from transformers==4.37.2) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\prakh\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.37.2) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\prakh\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.37.2) (4.7.1)
# Requirement already satisfied: colorama in c:\users\prakh\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.37.2) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prakh\anaconda3\lib\site-packages (from requests->transformers==4.37.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prakh\anaconda3\lib\site-packages (from requests->transformers==4.37.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prakh\anaconda3\lib\site-packages (from requests->transformers==4.37.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prakh\anaconda3\lib\site-packages (from requests->transformers==4.37.2) (2024.2.2)

# %% [markdown]
# ## sentiment-analysis

# %%
# !set HF_DATASETS_OFFLINE=1 
# !set TRANSFORMERS_OFFLINE=1
# !python -c "from transformers import pipeline; print(pipeline('sentiment-analysis')('I love you'))"
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998656511306763}]
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %% [markdown]
# ## text-to-speech

# %%
from transformers import pipeline
from IPython.display import Audio

pipe = pipeline("text-to-speech", model="suno/bark-small")
text = "[clears throat] This is a test ... and I just took a long pause."
output = pipe(text)

Audio(output["audio"], rate=output["sampling_rate"])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
